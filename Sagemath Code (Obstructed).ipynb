# %%
from scipy.optimize import linprog
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# =============================================================================
# HELPER FUNCTIONS
# =============================================================================

def travel_time(distance_m, speed=1.2):
    """Travel time in seconds. Default speed = corridor (1.2 m/s)."""
    return round(distance_m / speed)

def corridor_cap(width_m):
    """Corridor flow capacity: 60 persons/min per metre width (=persons/s *600)."""
    return round(width_m * 600)

def stair_cap(width_m, evac_minutes=20):
    """
    Stair total throughput capacity for a static MCF formulation.
    SFPE: 40 persons/min per metre width.
    Multiply by evacuation duration to get total persons that can pass through
    the stairwell over the full evacuation.
    Scenario: evac_minutes raised from 15 -> 20 to account for degraded egress
    conditions (center stairwell lost to fire). At 20 min, the two remaining
    stairs provide capacity for ~2,400 upper-floor occupants, which clears all
    weekday loads (worst case: Thursday at 1,991 persons) with headroom.
    """
    return round(width_m * 40 * evac_minutes)

def door_cap(width_m):
    """Door flow capacity: 60 persons/min per metre clear width."""
    return round(width_m * 600)

SPEED_CORRIDOR = 1.2   # m/s
SPEED_STAIR    = 0.6   # m/s
SPEED_DOOR     = 0.5   # m/s

# =============================================================================
# 1. NODE DEFINITIONS
# =============================================================================

ROOMS = [
    # Ground Floor
    "GF_FH106", "GF_FH107", "GF_FH108", "GF_FH110",
    "GF_MTLABA", "GF_MTLABB", "GF_GS", "GF_PSR", "GF_FR", "GF_CSR",
    # Second Floor
    "SF_FH201A", "SF_FH201B", "SF_FH202", "SF_FH205", "SF_FH206", "SF_FH207",
    "SF_RE", "SF_CSAR", "SF_AVRA", "SF_AVRB",
    "SF_FH208", "SF_FH209", "SF_FH210", "SF_MMR", "SF_STD",
    "SF_OCL2", "SF_SL", "SF_OCL", "SF_CTA", "SF_CTB", "SF_CTC",
    "SF_DO", "SF_FR",
    # Third Floor
    "TF_FH301A", "TF_FH302", "TF_FH303", "TF_FH304", "TF_FH305",
    "TF_FH306", "TF_FH307", "TF_FH308", "TF_FH309",
    "TF_FH311A", "TF_FH311B", "TF_FHCL", "TF_OAC", "TF_FHTL",
    "TF_FH314", "TF_FH315", "TF_FH316", "TF_FH317",
    "TF_DO", "TF_FR",
]

# CENTER stair nodes are kept in the node list for index consistency,
# but have NO edges connecting them — effectively isolated/impassable.
CORRIDORS = [
    "GF_JUNC_LEFT", "GF_JUNC_CENTER", "GF_JUNC_RIGHT",
    "SF_JUNC_LEFT", "SF_JUNC_CENTER", "SF_JUNC_RIGHT",
    "TF_JUNC_LEFT", "TF_JUNC_CENTER", "TF_JUNC_RIGHT",
    "LEFT_STAIR_T2S",  "CENTER_STAIR_T2S",  "RIGHT_STAIR_T2S",
    "LEFT_STAIR_S2G",  "CENTER_STAIR_S2G",  "RIGHT_STAIR_S2G",
]

EXITS = [
    "GF_MAINEXIT1", "GF_MAINEXIT2", "GF_MAINEXIT3",
    "GF_MAINEXIT4", "GF_MAINEXIT5", "GF_MAINEXIT6", "GF_MAINEXIT7",
]

EVAC_AREAS   = ["EA_FRONT", "EA_LEFT", "EA_RIGHT"]
SUPER_SOURCE = "s*"
SUPER_SINK   = "t*"
DAYS         = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday"]

# =============================================================================
# 2. EVACUATION AREA CAPACITIES
# =============================================================================

DELTA = 0.54  # m² per person (SFPE standard)

EVAC_AREA_DATA = {
    # SCENARIO CHANGE: EA_FRONT reduced from 2800.0 to 1400.0 m²
    "EA_FRONT": 1400.0,
    "EA_LEFT":   270.0,
    "EA_RIGHT":  185.0,
}

EVAC_CAP = {a: int(EVAC_AREA_DATA[a] / DELTA) for a in EVAC_AREAS}

# =============================================================================
# 3. DAILY OCCUPANCY  (unchanged)
# =============================================================================

DAILY_SUPPLY = {
    "Monday": {
        "GF_FH106": 53, "GF_FH107": 56, "GF_FH108": 38, "GF_FH110": 59,
        "GF_MTLABA": 45, "GF_MTLABB": 41, "GF_GS": 12, "GF_PSR": 5,
        "GF_FR": 40, "GF_CSR": 5,
        "SF_FH201A": 47, "SF_FH201B": 60, "SF_FH202": 61, "SF_FH205": 29,
        "SF_FH206": 49, "SF_FH207": 49, "SF_RE": 44, "SF_CSAR": 67,
        "SF_AVRA": 46, "SF_AVRB": 36, "SF_FH208": 47, "SF_FH209": 56,
        "SF_FH210": 34, "SF_MMR": 51, "SF_STD": 0, "SF_OCL2": 53,
        "SF_SL": 47, "SF_OCL": 51, "SF_CTA": 53, "SF_CTB": 56,
        "SF_CTC": 56, "SF_DO": 6, "SF_FR": 30,
        "TF_FH301A": 55, "TF_FH302": 53, "TF_FH303": 50, "TF_FH304": 50,
        "TF_FH305": 51, "TF_FH306": 56, "TF_FH307": 51, "TF_FH308": 55,
        "TF_FH309": 46, "TF_FH311A": 57, "TF_FH311B": 47, "TF_FHCL": 55,
        "TF_OAC": 53, "TF_FHTL": 49, "TF_FH314": 47, "TF_FH315": 42,
        "TF_FH316": 43, "TF_FH317": 53, "TF_DO": 5, "TF_FR": 35,
    },
    "Tuesday": {
        "GF_FH106": 53, "GF_FH107": 49, "GF_FH108": 42, "GF_FH110": 59,
        "GF_MTLABA": 45, "GF_MTLABB": 44, "GF_GS": 12, "GF_PSR": 5,
        "GF_FR": 40, "GF_CSR": 5,
        "SF_FH201A": 59, "SF_FH201B": 61, "SF_FH202": 44, "SF_FH205": 46,
        "SF_FH206": 50, "SF_FH207": 37, "SF_RE": 34, "SF_CSAR": 47,
        "SF_AVRA": 47, "SF_AVRB": 45, "SF_FH208": 48, "SF_FH209": 57,
        "SF_FH210": 34, "SF_MMR": 56, "SF_STD": 51, "SF_OCL2": 51,
        "SF_SL": 48, "SF_OCL": 52, "SF_CTA": 48, "SF_CTB": 49,
        "SF_CTC": 51, "SF_DO": 6, "SF_FR": 30,
        "TF_FH301A": 31, "TF_FH302": 49, "TF_FH303": 53, "TF_FH304": 47,
        "TF_FH305": 40, "TF_FH306": 49, "TF_FH307": 57, "TF_FH308": 46,
        "TF_FH309": 53, "TF_FH311A": 54, "TF_FH311B": 46, "TF_FHCL": 38,
        "TF_OAC": 53, "TF_FHTL": 43, "TF_FH314": 57, "TF_FH315": 49,
        "TF_FH316": 43, "TF_FH317": 53, "TF_DO": 5, "TF_FR": 35,
    },
    "Wednesday": {
        "GF_FH106": 53, "GF_FH107": 33, "GF_FH108": 38, "GF_FH110": 59,
        "GF_MTLABA": 43, "GF_MTLABB": 44, "GF_GS": 12, "GF_PSR": 5,
        "GF_FR": 40, "GF_CSR": 5,
        "SF_FH201A": 59, "SF_FH201B": 48, "SF_FH202": 47, "SF_FH205": 60,
        "SF_FH206": 60, "SF_FH207": 44, "SF_RE": 44, "SF_CSAR": 44,
        "SF_AVRA": 61, "SF_AVRB": 45, "SF_FH208": 51, "SF_FH209": 44,
        "SF_FH210": 29, "SF_MMR": 46, "SF_STD": 50, "SF_OCL2": 49,
        "SF_SL": 49, "SF_OCL": 53, "SF_CTA": 49, "SF_CTB": 47,
        "SF_CTC": 44, "SF_DO": 6, "SF_FR": 30,
        "TF_FH301A": 55, "TF_FH302": 47, "TF_FH303": 49, "TF_FH304": 38,
        "TF_FH305": 55, "TF_FH306": 56, "TF_FH307": 46, "TF_FH308": 43,
        "TF_FH309": 47, "TF_FH311A": 47, "TF_FH311B": 43, "TF_FHCL": 42,
        "TF_OAC": 51, "TF_FHTL": 57, "TF_FH314": 57, "TF_FH315": 47,
        "TF_FH316": 41, "TF_FH317": 50, "TF_DO": 5, "TF_FR": 35,
    },
    "Thursday": {
        "GF_FH106": 56, "GF_FH107": 59, "GF_FH108": 39, "GF_FH110": 53,
        "GF_MTLABA": 45, "GF_MTLABB": 41, "GF_GS": 12, "GF_PSR": 5,
        "GF_FR": 40, "GF_CSR": 5,
        "SF_FH201A": 47, "SF_FH201B": 53, "SF_FH202": 61, "SF_FH205": 56,
        "SF_FH206": 56, "SF_FH207": 56, "SF_RE": 47, "SF_CSAR": 46,
        "SF_AVRA": 47, "SF_AVRB": 59, "SF_FH208": 44, "SF_FH209": 53,
        "SF_FH210": 52, "SF_MMR": 49, "SF_STD": 53, "SF_OCL2": 53,
        "SF_SL": 45, "SF_OCL": 56, "SF_CTA": 36, "SF_CTB": 35,
        "SF_CTC": 56, "SF_DO": 6, "SF_FR": 30,
        "TF_FH301A": 47, "TF_FH302": 45, "TF_FH303": 43, "TF_FH304": 41,
        "TF_FH305": 43, "TF_FH306": 51, "TF_FH307": 46, "TF_FH308": 47,
        "TF_FH309": 49, "TF_FH311A": 51, "TF_FH311B": 49, "TF_FHCL": 40,
        "TF_OAC": 50, "TF_FHTL": 57, "TF_FH314": 47, "TF_FH315": 57,
        "TF_FH316": 41, "TF_FH317": 51, "TF_DO": 5, "TF_FR": 35,
    },
    "Friday": {
        "GF_FH106": 46, "GF_FH107": 34, "GF_FH108": 53, "GF_FH110": 53,
        "GF_MTLABA": 45, "GF_MTLABB": 44, "GF_GS": 12, "GF_PSR": 5,
        "GF_FR": 40, "GF_CSR": 5,
        "SF_FH201A": 53, "SF_FH201B": 59, "SF_FH202": 61, "SF_FH205": 46,
        "SF_FH206": 56, "SF_FH207": 46, "SF_RE": 42, "SF_CSAR": 56,
        "SF_AVRA": 53, "SF_AVRB": 44, "SF_FH208": 51, "SF_FH209": 53,
        "SF_FH210": 0,  "SF_MMR": 46, "SF_STD": 53, "SF_OCL2": 53,
        "SF_SL": 49, "SF_OCL": 50, "SF_CTA": 41, "SF_CTB": 48,
        "SF_CTC": 53, "SF_DO": 6, "SF_FR": 30,
        "TF_FH301A": 47, "TF_FH302": 47, "TF_FH303": 39, "TF_FH304": 43,
        "TF_FH305": 54, "TF_FH306": 46, "TF_FH307": 50, "TF_FH308": 47,
        "TF_FH309": 55, "TF_FH311A": 50, "TF_FH311B": 57, "TF_FHCL": 40,
        "TF_OAC": 51, "TF_FHTL": 51, "TF_FH314": 47, "TF_FH315": 47,
        "TF_FH316": 55, "TF_FH317": 48, "TF_DO": 5, "TF_FR": 35,
    },
    "Saturday": {
        "GF_FH106": 53, "GF_FH107": 0,  "GF_FH108": 0,  "GF_FH110": 53,
        "GF_MTLABA": 30, "GF_MTLABB": 0, "GF_GS": 12, "GF_PSR": 2,
        "GF_FR": 20, "GF_CSR": 2,
        "SF_FH201A": 0,  "SF_FH201B": 0,  "SF_FH202": 0,  "SF_FH205": 45,
        "SF_FH206": 0,  "SF_FH207": 45, "SF_RE": 0,  "SF_CSAR": 0,
        "SF_AVRA": 0,  "SF_AVRB": 0,  "SF_FH208": 53, "SF_FH209": 53,
        "SF_FH210": 0,  "SF_MMR": 0,  "SF_STD": 47, "SF_OCL2": 30,
        "SF_SL": 43, "SF_OCL": 0,  "SF_CTA": 53, "SF_CTB": 0,
        "SF_CTC": 0,  "SF_DO": 2,  "SF_FR": 15,
        "TF_FH301A": 0,  "TF_FH302": 53, "TF_FH303": 0,  "TF_FH304": 55,
        "TF_FH305": 0,  "TF_FH306": 0,  "TF_FH307": 0,  "TF_FH308": 0,
        "TF_FH309": 0,  "TF_FH311A": 57, "TF_FH311B": 49, "TF_FHCL": 36,
        "TF_OAC": 51, "TF_FHTL": 49, "TF_FH314": 47, "TF_FH315": 47,
        "TF_FH316": 43, "TF_FH317": 50, "TF_DO": 2,  "TF_FR": 15,
    },
}

# =============================================================================
# 4. EDGE DEFINITIONS
# =============================================================================
def E(u, v, cap, cost):
    return (u, v, cap, cost)

ONE_FLOOR_STAIR = travel_time(3.8, SPEED_STAIR)   # ~6 s per floor

EDGES_BASE = [

    # =========================================================================
    # GROUND FLOOR
    # =========================================================================
    E("GF_FH106",  "GF_JUNC_LEFT",   door_cap(1.2), travel_time(6.0)),
    E("GF_FH107",  "GF_JUNC_LEFT",   door_cap(1.2), travel_time(8.0)),
    E("GF_FH108",  "GF_JUNC_LEFT",   door_cap(1.0), travel_time(10.0)),
    E("GF_MTLABA", "GF_JUNC_LEFT",   door_cap(1.2), travel_time(12.0)),
    E("GF_MTLABB", "GF_JUNC_LEFT",   door_cap(1.2), travel_time(14.0)),
    E("GF_GS",     "GF_JUNC_LEFT",   door_cap(1.0), travel_time(5.0)),
    E("GF_PSR",    "GF_JUNC_LEFT",   door_cap(0.9), travel_time(6.0)),
    E("GF_FR",     "GF_JUNC_LEFT",   door_cap(1.0), travel_time(7.0)),
    E("GF_CSR",    "GF_JUNC_LEFT",   door_cap(0.9), travel_time(6.0)),
    E("GF_FH110",  "GF_JUNC_CENTER", door_cap(1.2), travel_time(6.0)),

    E("GF_JUNC_LEFT",   "GF_JUNC_CENTER", corridor_cap(2.4), travel_time(20.0)),
    E("GF_JUNC_CENTER", "GF_JUNC_LEFT",   corridor_cap(2.4), travel_time(20.0)),
    E("GF_JUNC_CENTER", "GF_JUNC_RIGHT",  corridor_cap(2.4), travel_time(20.0)),
    E("GF_JUNC_RIGHT",  "GF_JUNC_CENTER", corridor_cap(2.4), travel_time(20.0)),

    E("GF_JUNC_LEFT",   "GF_MAINEXIT1", door_cap(1.8), travel_time(3.0)),
    E("GF_JUNC_LEFT",   "GF_MAINEXIT2", door_cap(1.8), travel_time(4.0)),
    E("GF_JUNC_LEFT",   "GF_MAINEXIT3", door_cap(1.8), travel_time(8.0)),
    E("GF_JUNC_CENTER", "GF_MAINEXIT4", door_cap(2.0), travel_time(3.0)),
    E("GF_JUNC_CENTER", "GF_MAINEXIT5", door_cap(2.0), travel_time(3.0)),
    E("GF_JUNC_RIGHT",  "GF_MAINEXIT6", door_cap(1.8), travel_time(3.0)),
    E("GF_JUNC_RIGHT",  "GF_MAINEXIT7", door_cap(1.8), travel_time(5.0)),

    E("GF_MAINEXIT1", "EA_FRONT", door_cap(1.8), travel_time(15.0)),
    E("GF_MAINEXIT2", "EA_FRONT", door_cap(1.8), travel_time(12.0)),
    E("GF_MAINEXIT3", "EA_LEFT",  door_cap(1.8), travel_time(10.0)),
    E("GF_MAINEXIT4", "EA_LEFT",  door_cap(2.0), travel_time(8.0)),
    E("GF_MAINEXIT5", "EA_LEFT",  door_cap(2.0), travel_time(10.0)),
    E("GF_MAINEXIT6", "EA_RIGHT", door_cap(1.8), travel_time(10.0)),
    E("GF_MAINEXIT7", "EA_RIGHT", door_cap(1.8), travel_time(12.0)),

    # =========================================================================
    # SECOND FLOOR
    # =========================================================================
    E("SF_FH201A", "SF_JUNC_LEFT",   door_cap(1.2), travel_time(6.0)),
    E("SF_FH201B", "SF_JUNC_LEFT",   door_cap(1.2), travel_time(8.0)),
    E("SF_FH202",  "SF_JUNC_LEFT",   door_cap(1.2), travel_time(10.0)),
    E("SF_FH205",  "SF_JUNC_LEFT",   door_cap(1.2), travel_time(14.0)),
    E("SF_FH206",  "SF_JUNC_LEFT",   door_cap(1.2), travel_time(16.0)),
    E("SF_FH207",  "SF_JUNC_LEFT",   door_cap(1.2), travel_time(18.0)),
    E("SF_RE",     "SF_JUNC_LEFT",   door_cap(1.0), travel_time(5.0)),
    E("SF_CSAR",   "SF_JUNC_LEFT",   door_cap(1.5), travel_time(7.0)),
    E("SF_AVRA",   "SF_JUNC_CENTER", door_cap(1.5), travel_time(6.0)),
    E("SF_AVRB",   "SF_JUNC_CENTER", door_cap(1.5), travel_time(6.0)),
    E("SF_FH208",  "SF_JUNC_CENTER", door_cap(1.2), travel_time(8.0)),
    E("SF_FH209",  "SF_JUNC_CENTER", door_cap(1.2), travel_time(10.0)),
    E("SF_FH210",  "SF_JUNC_CENTER", door_cap(1.2), travel_time(10.0)),
    E("SF_MMR",    "SF_JUNC_CENTER", door_cap(1.2), travel_time(6.0)),
    E("SF_STD",    "SF_JUNC_CENTER", door_cap(1.2), travel_time(6.0)),
    E("SF_OCL2",   "SF_JUNC_RIGHT",  door_cap(1.2), travel_time(8.0)),
    E("SF_SL",     "SF_JUNC_RIGHT",  door_cap(1.2), travel_time(10.0)),
    E("SF_OCL",    "SF_JUNC_RIGHT",  door_cap(1.2), travel_time(12.0)),
    E("SF_CTA",    "SF_JUNC_RIGHT",  door_cap(1.2), travel_time(14.0)),
    E("SF_CTB",    "SF_JUNC_RIGHT",  door_cap(1.2), travel_time(16.0)),
    E("SF_CTC",    "SF_JUNC_RIGHT",  door_cap(1.2), travel_time(18.0)),
    E("SF_DO",     "SF_JUNC_RIGHT",  door_cap(0.9), travel_time(4.0)),
    E("SF_FR",     "SF_JUNC_RIGHT",  door_cap(1.0), travel_time(5.0)),

    E("SF_JUNC_LEFT",   "SF_JUNC_CENTER", corridor_cap(2.4), travel_time(22.0)),
    E("SF_JUNC_CENTER", "SF_JUNC_LEFT",   corridor_cap(2.4), travel_time(22.0)),
    E("SF_JUNC_CENTER", "SF_JUNC_RIGHT",  corridor_cap(2.4), travel_time(22.0)),
    E("SF_JUNC_RIGHT",  "SF_JUNC_CENTER", corridor_cap(2.4), travel_time(22.0)),

    # 2F → stair landings
    # CENTER stair REMOVED (impassable): SF_JUNC_CENTER → CENTER_STAIR_S2G omitted
    E("SF_JUNC_LEFT",  "LEFT_STAIR_S2G",  stair_cap(1.5), travel_time(5.0)),
    E("SF_JUNC_RIGHT", "RIGHT_STAIR_S2G", stair_cap(1.5), travel_time(5.0)),

    # Stair descent 2F → GF
    # CENTER stair REMOVED: CENTER_STAIR_S2G → GF_JUNC_CENTER omitted
    E("LEFT_STAIR_S2G",  "GF_JUNC_LEFT",  stair_cap(1.5), ONE_FLOOR_STAIR),
    E("RIGHT_STAIR_S2G", "GF_JUNC_RIGHT", stair_cap(1.5), ONE_FLOOR_STAIR),

    # =========================================================================
    # THIRD FLOOR
    # =========================================================================
    E("TF_FH301A", "TF_JUNC_LEFT",   door_cap(1.2), travel_time(6.0)),
    E("TF_FH302",  "TF_JUNC_LEFT",   door_cap(1.2), travel_time(8.0)),
    E("TF_FH303",  "TF_JUNC_LEFT",   door_cap(1.2), travel_time(10.0)),
    E("TF_FH304",  "TF_JUNC_LEFT",   door_cap(1.2), travel_time(12.0)),
    E("TF_FH305",  "TF_JUNC_LEFT",   door_cap(1.2), travel_time(14.0)),
    E("TF_FH306",  "TF_JUNC_LEFT",   door_cap(1.2), travel_time(16.0)),
    E("TF_FH307",  "TF_JUNC_LEFT",   door_cap(1.2), travel_time(18.0)),
    E("TF_FH308",  "TF_JUNC_CENTER", door_cap(1.2), travel_time(6.0)),
    E("TF_FH309",  "TF_JUNC_CENTER", door_cap(1.2), travel_time(8.0)),
    E("TF_FH311A", "TF_JUNC_CENTER", door_cap(1.2), travel_time(10.0)),
    E("TF_FH311B", "TF_JUNC_CENTER", door_cap(1.2), travel_time(10.0)),
    E("TF_FHCL",   "TF_JUNC_CENTER", door_cap(1.5), travel_time(6.0)),
    E("TF_OAC",    "TF_JUNC_CENTER", door_cap(1.2), travel_time(6.0)),
    E("TF_FHTL",   "TF_JUNC_CENTER", door_cap(1.2), travel_time(8.0)),
    E("TF_FH314",  "TF_JUNC_RIGHT",  door_cap(1.2), travel_time(8.0)),
    E("TF_FH315",  "TF_JUNC_RIGHT",  door_cap(1.2), travel_time(10.0)),
    E("TF_FH316",  "TF_JUNC_RIGHT",  door_cap(1.2), travel_time(12.0)),
    E("TF_FH317",  "TF_JUNC_RIGHT",  door_cap(1.2), travel_time(14.0)),
    E("TF_DO",     "TF_JUNC_RIGHT",  door_cap(0.9), travel_time(4.0)),
    E("TF_FR",     "TF_JUNC_RIGHT",  door_cap(1.0), travel_time(5.0)),

    E("TF_JUNC_LEFT",   "TF_JUNC_CENTER", corridor_cap(2.4), travel_time(22.0)),
    E("TF_JUNC_CENTER", "TF_JUNC_LEFT",   corridor_cap(2.4), travel_time(22.0)),
    E("TF_JUNC_CENTER", "TF_JUNC_RIGHT",  corridor_cap(2.4), travel_time(22.0)),
    E("TF_JUNC_RIGHT",  "TF_JUNC_CENTER", corridor_cap(2.4), travel_time(22.0)),

    # 3F → stair upper landings
    # CENTER stair REMOVED (impassable): TF_JUNC_CENTER → CENTER_STAIR_T2S omitted
    E("TF_JUNC_LEFT",  "LEFT_STAIR_T2S",  stair_cap(1.5), travel_time(5.0)),
    E("TF_JUNC_RIGHT", "RIGHT_STAIR_T2S", stair_cap(1.5), travel_time(5.0)),

    # Stair descent 3F → 2F
    # CENTER stair REMOVED: CENTER_STAIR_T2S → SF_JUNC_CENTER omitted
    E("LEFT_STAIR_T2S",  "SF_JUNC_LEFT",  stair_cap(1.5), ONE_FLOOR_STAIR),
    E("RIGHT_STAIR_T2S", "SF_JUNC_RIGHT", stair_cap(1.5), ONE_FLOOR_STAIR),
]

# =============================================================================
# 5. SOLVER
# =============================================================================

def build_and_solve(day_name, verbose=True):

    supply_data = DAILY_SUPPLY[day_name]
    supply = {room: supply_data.get(room, 0) for room in ROOMS}
    S = sum(supply.values())

    if verbose:
        print("=" * 65)
        print(f"  DAY: {day_name}   |   Total Evacuees (S) = {S}")
        print("=" * 65)

    total_cap = sum(EVAC_CAP.values())
    if total_cap < S:
        print(f"  [INFEASIBLE] Evac capacity ({total_cap}) < Supply ({S})\n")
        return None

    ss_edges = []
    for room in ROOMS:
        if supply[room] > 0:
            ss_edges.append((SUPER_SOURCE, room, supply[room], 0))
    for area in EVAC_AREAS:
        ss_edges.append((area, SUPER_SINK, EVAC_CAP[area], 0))

    ALL_EDGES = EDGES_BASE + ss_edges
    n_edges   = len(ALL_EDGES)

    ALL_NODES = ROOMS + CORRIDORS + EXITS + EVAC_AREAS + [SUPER_SOURCE, SUPER_SINK]
    node_idx  = {n: i for i, n in enumerate(ALL_NODES)}
    n_nodes   = len(ALL_NODES)

    c_obj  = np.array([cost for (_, _, _, cost) in ALL_EDGES], dtype=float)
    bounds = [(0, cap) for (_, _, cap, _) in ALL_EDGES]

    A_eq = np.zeros((n_nodes, n_edges))
    b_eq = np.zeros(n_nodes)

    for e_idx, (u, v, cap, cost) in enumerate(ALL_EDGES):
        if u in node_idx: A_eq[node_idx[u], e_idx] -= 1
        if v in node_idx: A_eq[node_idx[v], e_idx] += 1

    b_eq[node_idx[SUPER_SOURCE]] = -S
    b_eq[node_idx[SUPER_SINK]]   =  S

    result = linprog(c_obj, A_eq=A_eq, b_eq=b_eq, bounds=bounds, method='highs')

    if result.status != 0:
        print(f"  [SOLVER] {result.message}\n")
        return None

    flow_vals = result.x
    obj_val   = result.fun

    out_edges = {n: [] for n in ALL_NODES}
    in_edges  = {n: [] for n in ALL_NODES}
    for i, (u, v, cap, cost) in enumerate(ALL_EDGES):
        if u in out_edges: out_edges[u].append(i)
        if v in in_edges:  in_edges[v].append(i)

    if verbose:
        print(f"\n  Optimal Total Cost Z = {obj_val:.2f} (person-seconds)\n")
        print(f"  {'Edge':<50} {'Cap':>5} {'Flow':>7} {'Cost':>6} {'Util%':>7}")
        print("  " + "-" * 80)

        bottlenecks = []
        for i, (u, v, cap, cost) in enumerate(ALL_EDGES):
            if u == SUPER_SOURCE or v == SUPER_SINK:
                continue
            fv = flow_vals[i]
            if fv > 0.01:
                util = (fv / cap * 100) if cap > 0 else 0
                tag  = "  ⚠ BOTTLENECK" if util >= 90 else ""
                if util >= 90:
                    bottlenecks.append((u, v, cap, fv, util))
                edge_str = f"{u} → {v}"
                print(f"  {edge_str:<50} {cap:>5} {fv:>7.1f} {cost:>6} {util:>6.1f}%{tag}")

        print(f"\n  {'Evacuation Area':<20} {'Capacity':>10} {'Received':>10} {'Util%':>8}")
        print("  " + "-" * 52)
        for area in EVAC_AREAS:
            received = sum(flow_vals[i] for i in in_edges[area])
            util = received / EVAC_CAP[area] * 100
            print(f"  {area:<20} {EVAC_CAP[area]:>10} {received:>10.1f} {util:>7.1f}%")

        if bottlenecks:
            print(f"\n  ⚠  BOTTLENECK EDGES (>=90% utilization):")
            for u, v, cap, fv, util in bottlenecks:
                print(f"     {u} → {v}  |  Flow: {fv:.1f}/{cap}  ({util:.1f}%)")
        else:
            print(f"\n  ✓  No bottlenecks detected.")
        print()

    return {
        'day': day_name, 'total_supply': S, 'optimal_cost': obj_val,
        'flow_vals': flow_vals, 'edges': ALL_EDGES,
        'in_edges': in_edges, 'out_edges': out_edges,
    }

# =============================================================================
# 6. OPTIMAL ROUTE TRACER
# =============================================================================

def get_optimal_route(result, start_room, verbose=True):
    if result is None:
        return None

    edges, flow_vals = result['edges'], result['flow_vals']
    adj = {}
    for i, (u, v, cap, cost) in enumerate(edges):
        adj.setdefault(u, []).append((v, i))

    path, visited, current = [start_room], {start_room}, start_room
    terminals = set(EVAC_AREAS + [SUPER_SINK])

    while current not in terminals:
        candidates = [(v, idx) for v, idx in adj.get(current, []) if v not in visited]
        if not candidates:
            break
        best_v, best_idx = max(candidates, key=lambda x: flow_vals[x[1]])
        if flow_vals[best_idx] < 0.01:
            break
        path.append(best_v)
        visited.add(best_v)
        current = best_v

    display_path = [n for n in path if n != SUPER_SINK]
    if verbose:
        print(f"  {start_room:<15} →  {' → '.join(display_path[1:])}")
    return display_path

# =============================================================================
# 7. MAIN — RUN ALL DAYS
# =============================================================================

print("=" * 65)
print("  FEDERIZO HALL — EVACUATION FLOW OPTIMIZER")
print("  SENSITIVITY ANALYSIS SCENARIO:")
print("    * EA_FRONT = 1400 m2 (reduced from 2800 m2)")
print("    * CENTER STAIRWELL DISABLED (fire/impassable)")
print("    * evac_minutes = 17 min (raised from 15 — degraded egress)")
print("  Capacitated Multi-Source Multi-Sink Minimum Cost Flow")
print("  BulSU Main Campus")
print("=" * 65)
print(f"\n  Evacuation Area Capacities:")
for a, cap in EVAC_CAP.items():
    print(f"    {a:<12}  {EVAC_AREA_DATA[a]:>7} m2  ->  {cap:>5} persons")
print(f"    {'TOTAL':<12}  {'':>7}      {sum(EVAC_CAP.values()):>5} persons\n")

results = {}
for day in DAYS:
    results[day] = build_and_solve(day, verbose=True)

# =============================================================================
# 8. WEEKLY SUMMARY
# =============================================================================

print("\n" + "=" * 58)
print("  WEEKLY SUMMARY")
print(f"  {'Day':<12} {'Evacuees':>10} {'Optimal Z':>14} {'Status':>12}")
print("  " + "-" * 52)
for day in DAYS:
    r = results[day]
    if r:
        print(f"  {day:<12} {r['total_supply']:>10} {r['optimal_cost']:>14.2f}  FEASIBLE")
    else:
        print(f"  {day:<12} {'N/A':>10} {'N/A':>14}  INFEASIBLE")

# =============================================================================
# 9. FIXED WEEKLY ROUTES (based on Thursday — worst-case occupancy)
#
# Strategy: solve on the highest-occupancy day (Thursday, S=2346) to derive
# the most stressed routing policy, then apply those paths as the fixed
# evacuation plan for the entire week. This ensures the routes are valid
# even on the hardest day, and all lighter days are automatically covered.
# =============================================================================

FIXED_ROUTE_DAY = "Thursday"

print("\n" + "=" * 65)
print(f"  FIXED WEEKLY EVACUATION ROUTES")
print(f"  (Derived from {FIXED_ROUTE_DAY} — worst-case occupancy)")
print(f"  Applied uniformly across all days of the week.")
print("=" * 65)

r_fixed = results.get(FIXED_ROUTE_DAY)

if r_fixed:
    # Group rooms by floor for readable output
    floor_groups = {
        "GROUND FLOOR": [r for r in ROOMS if r.startswith("GF_")],
        "SECOND FLOOR":  [r for r in ROOMS if r.startswith("SF_")],
        "THIRD FLOOR":   [r for r in ROOMS if r.startswith("TF_")],
    }

    fixed_routes = {}  # store for validation step below

    for floor_label, room_list in floor_groups.items():
        print(f"\n  --- {floor_label} ---")
        for room in room_list:
            path = get_optimal_route(r_fixed, room, verbose=False)
            if path and len(path) > 1:
                # Strip internal junction/stair nodes for a clean display,
                # keeping only meaningful waypoints: room → stair nodes → exit → evac area
                KEEP = set(EXITS + EVAC_AREAS +
                           ["LEFT_STAIR_T2S", "RIGHT_STAIR_T2S",
                            "LEFT_STAIR_S2G", "RIGHT_STAIR_S2G"])
                display = [path[0]] + [n for n in path[1:] if n in KEEP]
                fixed_routes[room] = display
                print(f"  {room:<15} ->  {' -> '.join(display[1:])}")
            else:
                fixed_routes[room] = path or [room]
                print(f"  {room:<15} ->  (no active flow on {FIXED_ROUTE_DAY})")


    print("\n" + "=" * 65)
    print("  FIXED ROUTE FEASIBILITY CHECK — ALL DAYS")
    print("  Verifying Thursday-derived routes hold across the week.")
    print("=" * 65)

    for day in DAYS:
        r_day = results[day]
        status = "FEASIBLE" if r_day else "INFEASIBLE"
        print(f"\n  {day} ({status})")
        if r_day is None:
            continue
        mismatches = 0
        for room in ROOMS:
            path_day = get_optimal_route(r_day, room, verbose=False)
            path_fixed = fixed_routes.get(room, [])
            # Check if the fixed route destination (evac area) matches
            dest_fixed = path_fixed[-1] if path_fixed else None
            dest_day   = path_day[-1]   if path_day   else None
            if dest_fixed and dest_day and dest_fixed != dest_day:
                print(f"    NOTE  {room}: fixed→{dest_fixed}, {day}→{dest_day}")
                mismatches += 1
        if mismatches == 0:
            print(f"    All rooms reach the same evacuation area as fixed plan.")
# Out:
# =================================================================
#   FEDERIZO HALL — EVACUATION FLOW OPTIMIZER
#   SENSITIVITY ANALYSIS SCENARIO:
#     * EA_FRONT = 1400 m2 (reduced from 2800 m2)
#     * CENTER STAIRWELL DISABLED (fire/impassable)
#     * evac_minutes = 17 min (raised from 15 — degraded egress)
#   Capacitated Multi-Source Multi-Sink Minimum Cost Flow
#   BulSU Main Campus
# =================================================================
#
#   Evacuation Area Capacities:
#     EA_FRONT      1400.00000000000 m2  ->   2592 persons
#     EA_LEFT       270.000000000000 m2  ->    499 persons
#     EA_RIGHT      185.000000000000 m2  ->    342 persons
#     TOTAL                       3433 persons
#
# =================================================================
#   DAY: Monday   |   Total Evacuees (S) = 2335
# =================================================================
#
#   Optimal Total Cost Z = 96739.00 (person-seconds)
#
#   Edge                                                 Cap    Flow   Cost   Util%
#   --------------------------------------------------------------------------------
#   GF_FH106 → GF_JUNC_LEFT                              720    53.0      5    7.4%
#   GF_FH107 → GF_JUNC_LEFT                              720    56.0      7    7.8%
#   GF_FH108 → GF_JUNC_LEFT                              600    38.0      8    6.3%
#   GF_MTLABA → GF_JUNC_LEFT                             720    45.0     10    6.2%
#   GF_MTLABB → GF_JUNC_LEFT                             720    41.0     12    5.7%
#   GF_GS → GF_JUNC_LEFT                                 600    12.0      4    2.0%
#   GF_PSR → GF_JUNC_LEFT                                540     5.0      5    0.9%
#   GF_FR → GF_JUNC_LEFT                                 600    40.0      6    6.7%
#   GF_CSR → GF_JUNC_LEFT                                540     5.0      5    0.9%
#   GF_FH110 → GF_JUNC_CENTER                            720    59.0      5    8.2%
#   GF_JUNC_RIGHT → GF_JUNC_CENTER                      1440   439.0     17   30.5%
#   GF_JUNC_LEFT → GF_MAINEXIT1                         1080   414.0      3   38.3%
#   GF_JUNC_LEFT → GF_MAINEXIT2                         1080  1080.0      3  100.0%  ⚠ BOTTLENECK
#   GF_JUNC_LEFT → GF_MAINEXIT3                         1080     1.0      7    0.1%
#   GF_JUNC_CENTER → GF_MAINEXIT4                       1200   498.0      3   41.5%
#   GF_JUNC_RIGHT → GF_MAINEXIT6                        1080   342.0      3   31.7%
#   GF_MAINEXIT1 → EA_FRONT                             1080   414.0     13   38.3%
#   GF_MAINEXIT2 → EA_FRONT                             1080  1080.0     10  100.0%  ⚠ BOTTLENECK
#   GF_MAINEXIT3 → EA_LEFT                              1080     1.0      8    0.1%
#   GF_MAINEXIT4 → EA_LEFT                              1200   498.0      7   41.5%
#   GF_MAINEXIT6 → EA_RIGHT                             1080   342.0      8   31.7%
#   SF_FH201A → SF_JUNC_LEFT                             720    47.0      5    6.5%
#   SF_FH201B → SF_JUNC_LEFT                             720    60.0      7    8.3%
#   SF_FH202 → SF_JUNC_LEFT                              720    61.0      8    8.5%
#   SF_FH205 → SF_JUNC_LEFT                              720    29.0     12    4.0%
#   SF_FH206 → SF_JUNC_LEFT                              720    49.0     13    6.8%
#   SF_FH207 → SF_JUNC_LEFT                              720    49.0     15    6.8%
#   SF_RE → SF_JUNC_LEFT                                 600    44.0      4    7.3%
#   SF_CSAR → SF_JUNC_LEFT                               900    67.0      6    7.4%
#   SF_AVRA → SF_JUNC_CENTER                             900    46.0      5    5.1%
#   SF_AVRB → SF_JUNC_CENTER                             900    36.0      5    4.0%
#   SF_FH208 → SF_JUNC_CENTER                            720    47.0      7    6.5%
#   SF_FH209 → SF_JUNC_CENTER                            720    56.0      8    7.8%
#   SF_FH210 → SF_JUNC_CENTER                            720    34.0      8    4.7%
#   SF_MMR → SF_JUNC_CENTER                              720    51.0      5    7.1%
#   SF_OCL2 → SF_JUNC_RIGHT                              720    53.0      7    7.4%
#   SF_SL → SF_JUNC_RIGHT                                720    47.0      8    6.5%
#   SF_OCL → SF_JUNC_RIGHT                               720    51.0     10    7.1%
#   SF_CTA → SF_JUNC_RIGHT                               720    53.0     12    7.4%
#   SF_CTB → SF_JUNC_RIGHT                               720    56.0     13    7.8%
#   SF_CTC → SF_JUNC_RIGHT                               720    56.0     15    7.8%
#   SF_DO → SF_JUNC_RIGHT                                540     6.0      3    1.1%
#   SF_FR → SF_JUNC_RIGHT                                600    30.0      4    5.0%
#   SF_JUNC_CENTER → SF_JUNC_LEFT                       1440    66.0     18    4.6%
#   SF_JUNC_CENTER → SF_JUNC_RIGHT                      1440   204.0     18   14.2%
#   SF_JUNC_LEFT → LEFT_STAIR_S2G                       1200  1200.0      4  100.0%  ⚠ BOTTLENECK
#   SF_JUNC_RIGHT → RIGHT_STAIR_S2G                     1200   781.0      4   65.1%
#   LEFT_STAIR_S2G → GF_JUNC_LEFT                       1200  1200.0      6  100.0%  ⚠ BOTTLENECK
#   RIGHT_STAIR_S2G → GF_JUNC_RIGHT                     1200   781.0      6   65.1%
#   TF_FH301A → TF_JUNC_LEFT                             720    55.0      5    7.6%
#   TF_FH302 → TF_JUNC_LEFT                              720    53.0      7    7.4%
#   TF_FH303 → TF_JUNC_LEFT                              720    50.0      8    6.9%
#   TF_FH304 → TF_JUNC_LEFT                              720    50.0     10    6.9%
#   TF_FH305 → TF_JUNC_LEFT                              720    51.0     12    7.1%
#   TF_FH306 → TF_JUNC_LEFT                              720    56.0     13    7.8%
#   TF_FH307 → TF_JUNC_LEFT                              720    51.0     15    7.1%
#   TF_FH308 → TF_JUNC_CENTER                            720    55.0      5    7.6%
#   TF_FH309 → TF_JUNC_CENTER                            720    46.0      7    6.4%
#   TF_FH311A → TF_JUNC_CENTER                           720    57.0      8    7.9%
#   TF_FH311B → TF_JUNC_CENTER                           720    47.0      8    6.5%
#   TF_FHCL → TF_JUNC_CENTER                             900    55.0      5    6.1%
#   TF_OAC → TF_JUNC_CENTER                              720    53.0      5    7.4%
#   TF_FHTL → TF_JUNC_CENTER                             720    49.0      7    6.8%
#   TF_FH314 → TF_JUNC_RIGHT                             720    47.0      7    6.5%
#   TF_FH315 → TF_JUNC_RIGHT                             720    42.0      8    5.8%
#   TF_FH316 → TF_JUNC_RIGHT                             720    43.0     10    6.0%
#   TF_FH317 → TF_JUNC_RIGHT                             720    53.0     12    7.4%
#   TF_DO → TF_JUNC_RIGHT                                540     5.0      3    0.9%
#   TF_FR → TF_JUNC_RIGHT                                600    35.0      4    5.8%
#   TF_JUNC_CENTER → TF_JUNC_LEFT                       1440   362.0     18   25.1%
#   TF_JUNC_LEFT → LEFT_STAIR_T2S                       1200   728.0      4   60.7%
#   TF_JUNC_RIGHT → RIGHT_STAIR_T2S                     1200   225.0      4   18.8%
#   LEFT_STAIR_T2S → SF_JUNC_LEFT                       1200   728.0      6   60.7%
#   RIGHT_STAIR_T2S → SF_JUNC_RIGHT                     1200   225.0      6   18.8%
#
#   Evacuation Area        Capacity   Received    Util%
#   ----------------------------------------------------
#   EA_FRONT                   2592     1494.0    57.6%
#   EA_LEFT                     499      499.0   100.0%
#   EA_RIGHT                    342      342.0   100.0%
#
#   ⚠  BOTTLENECK EDGES (>=90% utilization):
#      GF_JUNC_LEFT → GF_MAINEXIT2  |  Flow: 1080.0/1080  (100.0%)
#      GF_MAINEXIT2 → EA_FRONT  |  Flow: 1080.0/1080  (100.0%)
#      SF_JUNC_LEFT → LEFT_STAIR_S2G  |  Flow: 1200.0/1200  (100.0%)
#      LEFT_STAIR_S2G → GF_JUNC_LEFT  |  Flow: 1200.0/1200  (100.0%)
#
# =================================================================
#   DAY: Tuesday   |   Total Evacuees (S) = 2306
# =================================================================
#
#   Optimal Total Cost Z = 95453.00 (person-seconds)
#
#   Edge                                                 Cap    Flow   Cost   Util%
#   --------------------------------------------------------------------------------
#   GF_FH106 → GF_JUNC_LEFT                              720    53.0      5    7.4%
#   GF_FH107 → GF_JUNC_LEFT                              720    49.0      7    6.8%
#   GF_FH108 → GF_JUNC_LEFT                              600    42.0      8    7.0%
#   GF_MTLABA → GF_JUNC_LEFT                             720    45.0     10    6.2%
#   GF_MTLABB → GF_JUNC_LEFT                             720    44.0     12    6.1%
#   GF_GS → GF_JUNC_LEFT                                 600    12.0      4    2.0%
#   GF_PSR → GF_JUNC_LEFT                                540     5.0      5    0.9%
#   GF_FR → GF_JUNC_LEFT                                 600    40.0      6    6.7%
#   GF_CSR → GF_JUNC_LEFT                                540     5.0      5    0.9%
#   GF_FH110 → GF_JUNC_CENTER                            720    59.0      5    8.2%
#   GF_JUNC_RIGHT → GF_JUNC_CENTER                      1440   410.0     17   28.5%
#   GF_JUNC_LEFT → GF_MAINEXIT1                         1080   385.0      3   35.6%
#   GF_JUNC_LEFT → GF_MAINEXIT2                         1080  1080.0      3  100.0%  ⚠ BOTTLENECK
#   GF_JUNC_LEFT → GF_MAINEXIT3                         1080    30.0      7    2.8%
#   GF_JUNC_CENTER → GF_MAINEXIT4                       1200   469.0      3   39.1%
#   GF_JUNC_RIGHT → GF_MAINEXIT6                        1080   342.0      3   31.7%
#   GF_MAINEXIT1 → EA_FRONT                             1080   385.0     13   35.6%
#   GF_MAINEXIT2 → EA_FRONT                             1080  1080.0     10  100.0%  ⚠ BOTTLENECK
#   GF_MAINEXIT3 → EA_LEFT                              1080    30.0      8    2.8%
#   GF_MAINEXIT4 → EA_LEFT                              1200   469.0      7   39.1%
#   GF_MAINEXIT6 → EA_RIGHT                             1080   342.0      8   31.7%
#   SF_FH201A → SF_JUNC_LEFT                             720    59.0      5    8.2%
#   SF_FH201B → SF_JUNC_LEFT                             720    61.0      7    8.5%
#   SF_FH202 → SF_JUNC_LEFT                              720    44.0      8    6.1%
#   SF_FH205 → SF_JUNC_LEFT                              720    46.0     12    6.4%
#   SF_FH206 → SF_JUNC_LEFT                              720    50.0     13    6.9%
#   SF_FH207 → SF_JUNC_LEFT                              720    37.0     15    5.1%
#   SF_RE → SF_JUNC_LEFT                                 600    34.0      4    5.7%
#   SF_CSAR → SF_JUNC_LEFT                               900    47.0      6    5.2%
#   SF_AVRA → SF_JUNC_CENTER                             900    47.0      5    5.2%
#   SF_AVRB → SF_JUNC_CENTER                             900    45.0      5    5.0%
#   SF_FH208 → SF_JUNC_CENTER                            720    48.0      7    6.7%
#   SF_FH209 → SF_JUNC_CENTER                            720    57.0      8    7.9%
#   SF_FH210 → SF_JUNC_CENTER                            720    34.0      8    4.7%
#   SF_MMR → SF_JUNC_CENTER                              720    56.0      5    7.8%
#   SF_STD → SF_JUNC_CENTER                              720    51.0      5    7.1%
#   SF_OCL2 → SF_JUNC_RIGHT                              720    51.0      7    7.1%
#   SF_SL → SF_JUNC_RIGHT                                720    48.0      8    6.7%
#   SF_OCL → SF_JUNC_RIGHT                               720    52.0     10    7.2%
#   SF_CTA → SF_JUNC_RIGHT                               720    48.0     12    6.7%
#   SF_CTB → SF_JUNC_RIGHT                               720    49.0     13    6.8%
#   SF_CTC → SF_JUNC_RIGHT                               720    51.0     15    7.1%
#   SF_DO → SF_JUNC_RIGHT                                540     6.0      3    1.1%
#   SF_FR → SF_JUNC_RIGHT                                600    30.0      4    5.0%
#   SF_JUNC_CENTER → SF_JUNC_LEFT                       1440   163.0     18   11.3%
#   SF_JUNC_CENTER → SF_JUNC_RIGHT                      1440   175.0     18   12.2%
#   SF_JUNC_LEFT → LEFT_STAIR_S2G                       1200  1200.0      4  100.0%  ⚠ BOTTLENECK
#   SF_JUNC_RIGHT → RIGHT_STAIR_S2G                     1200   752.0      4   62.7%
#   LEFT_STAIR_S2G → GF_JUNC_LEFT                       1200  1200.0      6  100.0%  ⚠ BOTTLENECK
#   RIGHT_STAIR_S2G → GF_JUNC_RIGHT                     1200   752.0      6   62.7%
#   TF_FH301A → TF_JUNC_LEFT                             720    31.0      5    4.3%
#   TF_FH302 → TF_JUNC_LEFT                              720    49.0      7    6.8%
#   TF_FH303 → TF_JUNC_LEFT                              720    53.0      8    7.4%
#   TF_FH304 → TF_JUNC_LEFT                              720    47.0     10    6.5%
#   TF_FH305 → TF_JUNC_LEFT                              720    40.0     12    5.6%
#   TF_FH306 → TF_JUNC_LEFT                              720    49.0     13    6.8%
#   TF_FH307 → TF_JUNC_LEFT                              720    57.0     15    7.9%
#   TF_FH308 → TF_JUNC_CENTER                            720    46.0      5    6.4%
#   TF_FH309 → TF_JUNC_CENTER                            720    53.0      7    7.4%
#   TF_FH311A → TF_JUNC_CENTER                           720    54.0      8    7.5%
#   TF_FH311B → TF_JUNC_CENTER                           720    46.0      8    6.4%
#   TF_FHCL → TF_JUNC_CENTER                             900    38.0      5    4.2%
#   TF_OAC → TF_JUNC_CENTER                              720    53.0      5    7.4%
#   TF_FHTL → TF_JUNC_CENTER                             720    43.0      7    6.0%
#   TF_FH314 → TF_JUNC_RIGHT                             720    57.0      7    7.9%
#   TF_FH315 → TF_JUNC_RIGHT                             720    49.0      8    6.8%
#   TF_FH316 → TF_JUNC_RIGHT                             720    43.0     10    6.0%
#   TF_FH317 → TF_JUNC_RIGHT                             720    53.0     12    7.4%
#   TF_DO → TF_JUNC_RIGHT                                540     5.0      3    0.9%
#   TF_FR → TF_JUNC_RIGHT                                600    35.0      4    5.8%
#   TF_JUNC_CENTER → TF_JUNC_LEFT                       1440   333.0     18   23.1%
#   TF_JUNC_LEFT → LEFT_STAIR_T2S                       1200   659.0      4   54.9%
#   TF_JUNC_RIGHT → RIGHT_STAIR_T2S                     1200   242.0      4   20.2%
#   LEFT_STAIR_T2S → SF_JUNC_LEFT                       1200   659.0      6   54.9%
#   RIGHT_STAIR_T2S → SF_JUNC_RIGHT                     1200   242.0      6   20.2%
#
#   Evacuation Area        Capacity   Received    Util%
#   ----------------------------------------------------
#   EA_FRONT                   2592     1465.0    56.5%
#   EA_LEFT                     499      499.0   100.0%
#   EA_RIGHT                    342      342.0   100.0%
#
#   ⚠  BOTTLENECK EDGES (>=90% utilization):
#      GF_JUNC_LEFT → GF_MAINEXIT2  |  Flow: 1080.0/1080  (100.0%)
#      GF_MAINEXIT2 → EA_FRONT  |  Flow: 1080.0/1080  (100.0%)
#      SF_JUNC_LEFT → LEFT_STAIR_S2G  |  Flow: 1200.0/1200  (100.0%)
#      LEFT_STAIR_S2G → GF_JUNC_LEFT  |  Flow: 1200.0/1200  (100.0%)
#
# =================================================================
#   DAY: Wednesday   |   Total Evacuees (S) = 2302
# =================================================================
#
#   Optimal Total Cost Z = 95575.00 (person-seconds)
#
#   Edge                                                 Cap    Flow   Cost   Util%
#   --------------------------------------------------------------------------------
#   GF_FH106 → GF_JUNC_LEFT                              720    53.0      5    7.4%
#   GF_FH107 → GF_JUNC_LEFT                              720    33.0      7    4.6%
#   GF_FH108 → GF_JUNC_LEFT                              600    38.0      8    6.3%
#   GF_MTLABA → GF_JUNC_LEFT                             720    43.0     10    6.0%
#   GF_MTLABB → GF_JUNC_LEFT                             720    44.0     12    6.1%
#   GF_GS → GF_JUNC_LEFT                                 600    12.0      4    2.0%
#   GF_PSR → GF_JUNC_LEFT                                540     5.0      5    0.9%
#   GF_FR → GF_JUNC_LEFT                                 600    40.0      6    6.7%
#   GF_CSR → GF_JUNC_LEFT                                540     5.0      5    0.9%
#   GF_FH110 → GF_JUNC_CENTER                            720    59.0      5    8.2%
#   GF_JUNC_RIGHT → GF_JUNC_CENTER                      1440   428.0     17   29.7%
#   GF_JUNC_LEFT → GF_MAINEXIT1                         1080   381.0      3   35.3%
#   GF_JUNC_LEFT → GF_MAINEXIT2                         1080  1080.0      3  100.0%  ⚠ BOTTLENECK
#   GF_JUNC_LEFT → GF_MAINEXIT3                         1080    12.0      7    1.1%
#   GF_JUNC_CENTER → GF_MAINEXIT4                       1200   487.0      3   40.6%
#   GF_JUNC_RIGHT → GF_MAINEXIT6                        1080   342.0      3   31.7%
#   GF_MAINEXIT1 → EA_FRONT                             1080   381.0     13   35.3%
#   GF_MAINEXIT2 → EA_FRONT                             1080  1080.0     10  100.0%  ⚠ BOTTLENECK
#   GF_MAINEXIT3 → EA_LEFT                              1080    12.0      8    1.1%
#   GF_MAINEXIT4 → EA_LEFT                              1200   487.0      7   40.6%
#   GF_MAINEXIT6 → EA_RIGHT                             1080   342.0      8   31.7%
#   SF_FH201A → SF_JUNC_LEFT                             720    59.0      5    8.2%
#   SF_FH201B → SF_JUNC_LEFT                             720    48.0      7    6.7%
#   SF_FH202 → SF_JUNC_LEFT                              720    47.0      8    6.5%
#   SF_FH205 → SF_JUNC_LEFT                              720    60.0     12    8.3%
#   SF_FH206 → SF_JUNC_LEFT                              720    60.0     13    8.3%
#   SF_FH207 → SF_JUNC_LEFT                              720    44.0     15    6.1%
#   SF_RE → SF_JUNC_LEFT                                 600    44.0      4    7.3%
#   SF_CSAR → SF_JUNC_LEFT                               900    44.0      6    4.9%
#   SF_AVRA → SF_JUNC_CENTER                             900    61.0      5    6.8%
#   SF_AVRB → SF_JUNC_CENTER                             900    45.0      5    5.0%
#   SF_FH208 → SF_JUNC_CENTER                            720    51.0      7    7.1%
#   SF_FH209 → SF_JUNC_CENTER                            720    44.0      8    6.1%
#   SF_FH210 → SF_JUNC_CENTER                            720    29.0      8    4.0%
#   SF_MMR → SF_JUNC_CENTER                              720    46.0      5    6.4%
#   SF_STD → SF_JUNC_CENTER                              720    50.0      5    6.9%
#   SF_OCL2 → SF_JUNC_RIGHT                              720    49.0      7    6.8%
#   SF_SL → SF_JUNC_RIGHT                                720    49.0      8    6.8%
#   SF_OCL → SF_JUNC_RIGHT                               720    53.0     10    7.4%
#   SF_CTA → SF_JUNC_RIGHT                               720    49.0     12    6.8%
#   SF_CTB → SF_JUNC_RIGHT                               720    47.0     13    6.5%
#   SF_CTC → SF_JUNC_RIGHT                               720    44.0     15    6.1%
#   SF_DO → SF_JUNC_RIGHT                                540     6.0      3    1.1%
#   SF_FR → SF_JUNC_RIGHT                                600    30.0      4    5.0%
#   SF_JUNC_CENTER → SF_JUNC_LEFT                       1440   118.0     18    8.2%
#   SF_JUNC_CENTER → SF_JUNC_RIGHT                      1440   208.0     18   14.4%
#   SF_JUNC_LEFT → LEFT_STAIR_S2G                       1200  1200.0      4  100.0%  ⚠ BOTTLENECK
#   SF_JUNC_RIGHT → RIGHT_STAIR_S2G                     1200   770.0      4   64.2%
#   LEFT_STAIR_S2G → GF_JUNC_LEFT                       1200  1200.0      6  100.0%  ⚠ BOTTLENECK
#   RIGHT_STAIR_S2G → GF_JUNC_RIGHT                     1200   770.0      6   64.2%
#   TF_FH301A → TF_JUNC_LEFT                             720    55.0      5    7.6%
#   TF_FH302 → TF_JUNC_LEFT                              720    47.0      7    6.5%
#   TF_FH303 → TF_JUNC_LEFT                              720    49.0      8    6.8%
#   TF_FH304 → TF_JUNC_LEFT                              720    38.0     10    5.3%
#   TF_FH305 → TF_JUNC_LEFT                              720    55.0     12    7.6%
#   TF_FH306 → TF_JUNC_LEFT                              720    56.0     13    7.8%
#   TF_FH307 → TF_JUNC_LEFT                              720    46.0     15    6.4%
#   TF_FH308 → TF_JUNC_CENTER                            720    43.0      5    6.0%
#   TF_FH309 → TF_JUNC_CENTER                            720    47.0      7    6.5%
#   TF_FH311A → TF_JUNC_CENTER                           720    47.0      8    6.5%
#   TF_FH311B → TF_JUNC_CENTER                           720    43.0      8    6.0%
#   TF_FHCL → TF_JUNC_CENTER                             900    42.0      5    4.7%
#   TF_OAC → TF_JUNC_CENTER                              720    51.0      5    7.1%
#   TF_FHTL → TF_JUNC_CENTER                             720    57.0      7    7.9%
#   TF_FH314 → TF_JUNC_RIGHT                             720    57.0      7    7.9%
#   TF_FH315 → TF_JUNC_RIGHT                             720    47.0      8    6.5%
#   TF_FH316 → TF_JUNC_RIGHT                             720    41.0     10    5.7%
#   TF_FH317 → TF_JUNC_RIGHT                             720    50.0     12    6.9%
#   TF_DO → TF_JUNC_RIGHT                                540     5.0      3    0.9%
#   TF_FR → TF_JUNC_RIGHT                                600    35.0      4    5.8%
#   TF_JUNC_CENTER → TF_JUNC_LEFT                       1440   330.0     18   22.9%
#   TF_JUNC_LEFT → LEFT_STAIR_T2S                       1200   676.0      4   56.3%
#   TF_JUNC_RIGHT → RIGHT_STAIR_T2S                     1200   235.0      4   19.6%
#   LEFT_STAIR_T2S → SF_JUNC_LEFT                       1200   676.0      6   56.3%
#   RIGHT_STAIR_T2S → SF_JUNC_RIGHT                     1200   235.0      6   19.6%
#
#   Evacuation Area        Capacity   Received    Util%
#   ----------------------------------------------------
#   EA_FRONT                   2592     1461.0    56.4%
#   EA_LEFT                     499      499.0   100.0%
#   EA_RIGHT                    342      342.0   100.0%
#
#   ⚠  BOTTLENECK EDGES (>=90% utilization):
#      GF_JUNC_LEFT → GF_MAINEXIT2  |  Flow: 1080.0/1080  (100.0%)
#      GF_MAINEXIT2 → EA_FRONT  |  Flow: 1080.0/1080  (100.0%)
#      SF_JUNC_LEFT → LEFT_STAIR_S2G  |  Flow: 1200.0/1200  (100.0%)
#      LEFT_STAIR_S2G → GF_JUNC_LEFT  |  Flow: 1200.0/1200  (100.0%)
#
# =================================================================
#   DAY: Thursday   |   Total Evacuees (S) = 2346
# =================================================================
#
#   Optimal Total Cost Z = 97790.00 (person-seconds)
#
#   Edge                                                 Cap    Flow   Cost   Util%
#   --------------------------------------------------------------------------------
#   GF_FH106 → GF_JUNC_LEFT                              720    56.0      5    7.8%
#   GF_FH107 → GF_JUNC_LEFT                              720    59.0      7    8.2%
#   GF_FH108 → GF_JUNC_LEFT                              600    39.0      8    6.5%
#   GF_MTLABA → GF_JUNC_LEFT                             720    45.0     10    6.2%
#   GF_MTLABB → GF_JUNC_LEFT                             720    41.0     12    5.7%
#   GF_GS → GF_JUNC_LEFT                                 600    12.0      4    2.0%
#   GF_PSR → GF_JUNC_LEFT                                540     5.0      5    0.9%
#   GF_FR → GF_JUNC_LEFT                                 600    40.0      6    6.7%
#   GF_CSR → GF_JUNC_LEFT                                540     5.0      5    0.9%
#   GF_FH110 → GF_JUNC_CENTER                            720    53.0      5    7.4%
#   GF_JUNC_CENTER → GF_JUNC_LEFT                       1440     3.0     17    0.2%
#   GF_JUNC_RIGHT → GF_JUNC_CENTER                      1440   449.0     17   31.2%
#   GF_JUNC_LEFT → GF_MAINEXIT1                         1080   425.0      3   39.4%
#   GF_JUNC_LEFT → GF_MAINEXIT2                         1080  1080.0      3  100.0%  ⚠ BOTTLENECK
#   GF_JUNC_CENTER → GF_MAINEXIT4                       1200   499.0      3   41.6%
#   GF_JUNC_RIGHT → GF_MAINEXIT6                        1080   342.0      3   31.7%
#   GF_MAINEXIT1 → EA_FRONT                             1080   425.0     13   39.4%
#   GF_MAINEXIT2 → EA_FRONT                             1080  1080.0     10  100.0%  ⚠ BOTTLENECK
#   GF_MAINEXIT4 → EA_LEFT                              1200   499.0      7   41.6%
#   GF_MAINEXIT6 → EA_RIGHT                             1080   342.0      8   31.7%
#   SF_FH201A → SF_JUNC_LEFT                             720    47.0      5    6.5%
#   SF_FH201B → SF_JUNC_LEFT                             720    53.0      7    7.4%
#   SF_FH202 → SF_JUNC_LEFT                              720    61.0      8    8.5%
#   SF_FH205 → SF_JUNC_LEFT                              720    56.0     12    7.8%
#   SF_FH206 → SF_JUNC_LEFT                              720    56.0     13    7.8%
#   SF_FH207 → SF_JUNC_LEFT                              720    56.0     15    7.8%
#   SF_RE → SF_JUNC_LEFT                                 600    47.0      4    7.8%
#   SF_CSAR → SF_JUNC_LEFT                               900    46.0      6    5.1%
#   SF_AVRA → SF_JUNC_CENTER                             900    47.0      5    5.2%
#   SF_AVRB → SF_JUNC_CENTER                             900    59.0      5    6.6%
#   SF_FH208 → SF_JUNC_CENTER                            720    44.0      7    6.1%
#   SF_FH209 → SF_JUNC_CENTER                            720    53.0      8    7.4%
#   SF_FH210 → SF_JUNC_CENTER                            720    52.0      8    7.2%
#   SF_MMR → SF_JUNC_CENTER                              720    49.0      5    6.8%
#   SF_STD → SF_JUNC_CENTER                              720    53.0      5    7.4%
#   SF_OCL2 → SF_JUNC_RIGHT                              720    53.0      7    7.4%
#   SF_SL → SF_JUNC_RIGHT                                720    45.0      8    6.2%
#   SF_OCL → SF_JUNC_RIGHT                               720    56.0     10    7.8%
#   SF_CTA → SF_JUNC_RIGHT                               720    36.0     12    5.0%
#   SF_CTB → SF_JUNC_RIGHT                               720    35.0     13    4.9%
#   SF_CTC → SF_JUNC_RIGHT                               720    56.0     15    7.8%
#   SF_DO → SF_JUNC_RIGHT                                540     6.0      3    1.1%
#   SF_FR → SF_JUNC_RIGHT                                600    30.0      4    5.0%
#   SF_JUNC_CENTER → SF_JUNC_LEFT                       1440   119.0     18    8.3%
#   SF_JUNC_CENTER → SF_JUNC_RIGHT                      1440   238.0     18   16.5%
#   SF_JUNC_LEFT → LEFT_STAIR_S2G                       1200  1200.0      4  100.0%  ⚠ BOTTLENECK
#   SF_JUNC_RIGHT → RIGHT_STAIR_S2G                     1200   791.0      4   65.9%
#   LEFT_STAIR_S2G → GF_JUNC_LEFT                       1200  1200.0      6  100.0%  ⚠ BOTTLENECK
#   RIGHT_STAIR_S2G → GF_JUNC_RIGHT                     1200   791.0      6   65.9%
#   TF_FH301A → TF_JUNC_LEFT                             720    47.0      5    6.5%
#   TF_FH302 → TF_JUNC_LEFT                              720    45.0      7    6.2%
#   TF_FH303 → TF_JUNC_LEFT                              720    43.0      8    6.0%
#   TF_FH304 → TF_JUNC_LEFT                              720    41.0     10    5.7%
#   TF_FH305 → TF_JUNC_LEFT                              720    43.0     12    6.0%
#   TF_FH306 → TF_JUNC_LEFT                              720    51.0     13    7.1%
#   TF_FH307 → TF_JUNC_LEFT                              720    46.0     15    6.4%
#   TF_FH308 → TF_JUNC_CENTER                            720    47.0      5    6.5%
#   TF_FH309 → TF_JUNC_CENTER                            720    49.0      7    6.8%
#   TF_FH311A → TF_JUNC_CENTER                           720    51.0      8    7.1%
#   TF_FH311B → TF_JUNC_CENTER                           720    49.0      8    6.8%
#   TF_FHCL → TF_JUNC_CENTER                             900    40.0      5    4.4%
#   TF_OAC → TF_JUNC_CENTER                              720    50.0      5    6.9%
#   TF_FHTL → TF_JUNC_CENTER                             720    57.0      7    7.9%
#   TF_FH314 → TF_JUNC_RIGHT                             720    47.0      7    6.5%
#   TF_FH315 → TF_JUNC_RIGHT                             720    57.0      8    7.9%
#   TF_FH316 → TF_JUNC_RIGHT                             720    41.0     10    5.7%
#   TF_FH317 → TF_JUNC_RIGHT                             720    51.0     12    7.1%
#   TF_DO → TF_JUNC_RIGHT                                540     5.0      3    0.9%
#   TF_FR → TF_JUNC_RIGHT                                600    35.0      4    5.8%
#   TF_JUNC_CENTER → TF_JUNC_LEFT                       1440   343.0     18   23.8%
#   TF_JUNC_LEFT → LEFT_STAIR_T2S                       1200   659.0      4   54.9%
#   TF_JUNC_RIGHT → RIGHT_STAIR_T2S                     1200   236.0      4   19.7%
#   LEFT_STAIR_T2S → SF_JUNC_LEFT                       1200   659.0      6   54.9%
#   RIGHT_STAIR_T2S → SF_JUNC_RIGHT                     1200   236.0      6   19.7%
#
#   Evacuation Area        Capacity   Received    Util%
#   ----------------------------------------------------
#   EA_FRONT                   2592     1505.0    58.1%
#   EA_LEFT                     499      499.0   100.0%
#   EA_RIGHT                    342      342.0   100.0%
#
#   ⚠  BOTTLENECK EDGES (>=90% utilization):
#      GF_JUNC_LEFT → GF_MAINEXIT2  |  Flow: 1080.0/1080  (100.0%)
#      GF_MAINEXIT2 → EA_FRONT  |  Flow: 1080.0/1080  (100.0%)
#      SF_JUNC_LEFT → LEFT_STAIR_S2G  |  Flow: 1200.0/1200  (100.0%)
#      LEFT_STAIR_S2G → GF_JUNC_LEFT  |  Flow: 1200.0/1200  (100.0%)
#
# =================================================================
#   DAY: Friday   |   Total Evacuees (S) = 2300
# =================================================================
#
#   Optimal Total Cost Z = 95388.00 (person-seconds)
#
#   Edge                                                 Cap    Flow   Cost   Util%
#   --------------------------------------------------------------------------------
#   GF_FH106 → GF_JUNC_LEFT                              720    46.0      5    6.4%
#   GF_FH107 → GF_JUNC_LEFT                              720    34.0      7    4.7%
#   GF_FH108 → GF_JUNC_LEFT                              600    53.0      8    8.8%
#   GF_MTLABA → GF_JUNC_LEFT                             720    45.0     10    6.2%
#   GF_MTLABB → GF_JUNC_LEFT                             720    44.0     12    6.1%
#   GF_GS → GF_JUNC_LEFT                                 600    12.0      4    2.0%
#   GF_PSR → GF_JUNC_LEFT                                540     5.0      5    0.9%
#   GF_FR → GF_JUNC_LEFT                                 600    40.0      6    6.7%
#   GF_CSR → GF_JUNC_LEFT                                540     5.0      5    0.9%
#   GF_FH110 → GF_JUNC_CENTER                            720    53.0      5    7.4%
#   GF_JUNC_RIGHT → GF_JUNC_CENTER                      1440   421.0     17   29.2%
#   GF_JUNC_LEFT → GF_MAINEXIT1                         1080   379.0      3   35.1%
#   GF_JUNC_LEFT → GF_MAINEXIT2                         1080  1080.0      3  100.0%  ⚠ BOTTLENECK
#   GF_JUNC_LEFT → GF_MAINEXIT3                         1080    25.0      7    2.3%
#   GF_JUNC_CENTER → GF_MAINEXIT4                       1200   474.0      3   39.5%
#   GF_JUNC_RIGHT → GF_MAINEXIT6                        1080   342.0      3   31.7%
#   GF_MAINEXIT1 → EA_FRONT                             1080   379.0     13   35.1%
#   GF_MAINEXIT2 → EA_FRONT                             1080  1080.0     10  100.0%  ⚠ BOTTLENECK
#   GF_MAINEXIT3 → EA_LEFT                              1080    25.0      8    2.3%
#   GF_MAINEXIT4 → EA_LEFT                              1200   474.0      7   39.5%
#   GF_MAINEXIT6 → EA_RIGHT                             1080   342.0      8   31.7%
#   SF_FH201A → SF_JUNC_LEFT                             720    53.0      5    7.4%
#   SF_FH201B → SF_JUNC_LEFT                             720    59.0      7    8.2%
#   SF_FH202 → SF_JUNC_LEFT                              720    61.0      8    8.5%
#   SF_FH205 → SF_JUNC_LEFT                              720    46.0     12    6.4%
#   SF_FH206 → SF_JUNC_LEFT                              720    56.0     13    7.8%
#   SF_FH207 → SF_JUNC_LEFT                              720    46.0     15    6.4%
#   SF_RE → SF_JUNC_LEFT                                 600    42.0      4    7.0%
#   SF_CSAR → SF_JUNC_LEFT                               900    56.0      6    6.2%
#   SF_AVRA → SF_JUNC_CENTER                             900    53.0      5    5.9%
#   SF_AVRB → SF_JUNC_CENTER                             900    44.0      5    4.9%
#   SF_FH208 → SF_JUNC_CENTER                            720    51.0      7    7.1%
#   SF_FH209 → SF_JUNC_CENTER                            720    53.0      8    7.4%
#   SF_MMR → SF_JUNC_CENTER                              720    46.0      5    6.4%
#   SF_STD → SF_JUNC_CENTER                              720    53.0      5    7.4%
#   SF_OCL2 → SF_JUNC_RIGHT                              720    53.0      7    7.4%
#   SF_SL → SF_JUNC_RIGHT                                720    49.0      8    6.8%
#   SF_OCL → SF_JUNC_RIGHT                               720    50.0     10    6.9%
#   SF_CTA → SF_JUNC_RIGHT                               720    41.0     12    5.7%
#   SF_CTB → SF_JUNC_RIGHT                               720    48.0     13    6.7%
#   SF_CTC → SF_JUNC_RIGHT                               720    53.0     15    7.4%
#   SF_DO → SF_JUNC_RIGHT                                540     6.0      3    1.1%
#   SF_FR → SF_JUNC_RIGHT                                600    30.0      4    5.0%
#   SF_JUNC_CENTER → SF_JUNC_LEFT                       1440   104.0     18    7.2%
#   SF_JUNC_CENTER → SF_JUNC_RIGHT                      1440   196.0     18   13.6%
#   SF_JUNC_LEFT → LEFT_STAIR_S2G                       1200  1200.0      4  100.0%  ⚠ BOTTLENECK
#   SF_JUNC_RIGHT → RIGHT_STAIR_S2G                     1200   763.0      4   63.6%
#   LEFT_STAIR_S2G → GF_JUNC_LEFT                       1200  1200.0      6  100.0%  ⚠ BOTTLENECK
#   RIGHT_STAIR_S2G → GF_JUNC_RIGHT                     1200   763.0      6   63.6%
#   TF_FH301A → TF_JUNC_LEFT                             720    47.0      5    6.5%
#   TF_FH302 → TF_JUNC_LEFT                              720    47.0      7    6.5%
#   TF_FH303 → TF_JUNC_LEFT                              720    39.0      8    5.4%
#   TF_FH304 → TF_JUNC_LEFT                              720    43.0     10    6.0%
#   TF_FH305 → TF_JUNC_LEFT                              720    54.0     12    7.5%
#   TF_FH306 → TF_JUNC_LEFT                              720    46.0     13    6.4%
#   TF_FH307 → TF_JUNC_LEFT                              720    50.0     15    6.9%
#   TF_FH308 → TF_JUNC_CENTER                            720    47.0      5    6.5%
#   TF_FH309 → TF_JUNC_CENTER                            720    55.0      7    7.6%
#   TF_FH311A → TF_JUNC_CENTER                           720    50.0      8    6.9%
#   TF_FH311B → TF_JUNC_CENTER                           720    57.0      8    7.9%
#   TF_FHCL → TF_JUNC_CENTER                             900    40.0      5    4.4%
#   TF_OAC → TF_JUNC_CENTER                              720    51.0      5    7.1%
#   TF_FHTL → TF_JUNC_CENTER                             720    51.0      7    7.1%
#   TF_FH314 → TF_JUNC_RIGHT                             720    47.0      7    6.5%
#   TF_FH315 → TF_JUNC_RIGHT                             720    47.0      8    6.5%
#   TF_FH316 → TF_JUNC_RIGHT                             720    55.0     10    7.6%
#   TF_FH317 → TF_JUNC_RIGHT                             720    48.0     12    6.7%
#   TF_DO → TF_JUNC_RIGHT                                540     5.0      3    0.9%
#   TF_FR → TF_JUNC_RIGHT                                600    35.0      4    5.8%
#   TF_JUNC_CENTER → TF_JUNC_LEFT                       1440   351.0     18   24.4%
#   TF_JUNC_LEFT → LEFT_STAIR_T2S                       1200   677.0      4   56.4%
#   TF_JUNC_RIGHT → RIGHT_STAIR_T2S                     1200   237.0      4   19.8%
#   LEFT_STAIR_T2S → SF_JUNC_LEFT                       1200   677.0      6   56.4%
#   RIGHT_STAIR_T2S → SF_JUNC_RIGHT                     1200   237.0      6   19.8%
#
#   Evacuation Area        Capacity   Received    Util%
#   ----------------------------------------------------
#   EA_FRONT                   2592     1459.0    56.3%
#   EA_LEFT                     499      499.0   100.0%
#   EA_RIGHT                    342      342.0   100.0%
#
#   ⚠  BOTTLENECK EDGES (>=90% utilization):
#      GF_JUNC_LEFT → GF_MAINEXIT2  |  Flow: 1080.0/1080  (100.0%)
#      GF_MAINEXIT2 → EA_FRONT  |  Flow: 1080.0/1080  (100.0%)
#      SF_JUNC_LEFT → LEFT_STAIR_S2G  |  Flow: 1200.0/1200  (100.0%)
#      LEFT_STAIR_S2G → GF_JUNC_LEFT  |  Flow: 1200.0/1200  (100.0%)
#
# =================================================================
#   DAY: Saturday   |   Total Evacuees (S) = 1112
# =================================================================
#
#   Optimal Total Cost Z = 44600.00 (person-seconds)
#
#   Edge                                                 Cap    Flow   Cost   Util%
#   --------------------------------------------------------------------------------
#   GF_FH106 → GF_JUNC_LEFT                              720    53.0      5    7.4%
#   GF_MTLABA → GF_JUNC_LEFT                             720    30.0     10    4.2%
#   GF_GS → GF_JUNC_LEFT                                 600    12.0      4    2.0%
#   GF_PSR → GF_JUNC_LEFT                                540     2.0      5    0.4%
#   GF_FR → GF_JUNC_LEFT                                 600    20.0      6    3.3%
#   GF_CSR → GF_JUNC_LEFT                                540     2.0      5    0.4%
#   GF_FH110 → GF_JUNC_CENTER                            720    53.0      5    7.4%
#   GF_JUNC_RIGHT → GF_JUNC_CENTER                      1440     5.0     17    0.3%
#   GF_JUNC_LEFT → GF_MAINEXIT2                         1080   712.0      3   65.9%
#   GF_JUNC_CENTER → GF_MAINEXIT4                       1200    58.0      3    4.8%
#   GF_JUNC_RIGHT → GF_MAINEXIT6                        1080   342.0      3   31.7%
#   GF_MAINEXIT2 → EA_FRONT                             1080   712.0     10   65.9%
#   GF_MAINEXIT4 → EA_LEFT                              1200    58.0      7    4.8%
#   GF_MAINEXIT6 → EA_RIGHT                             1080   342.0      8   31.7%
#   SF_FH205 → SF_JUNC_LEFT                              720    45.0     12    6.2%
#   SF_FH207 → SF_JUNC_LEFT                              720    45.0     15    6.2%
#   SF_FH208 → SF_JUNC_CENTER                            720    53.0      7    7.4%
#   SF_FH209 → SF_JUNC_CENTER                            720    53.0      8    7.4%
#   SF_STD → SF_JUNC_CENTER                              720    47.0      5    6.5%
#   SF_OCL2 → SF_JUNC_RIGHT                              720    30.0      7    4.2%
#   SF_SL → SF_JUNC_RIGHT                                720    43.0      8    6.0%
#   SF_CTA → SF_JUNC_RIGHT                               720    53.0     12    7.4%
#   SF_DO → SF_JUNC_RIGHT                                540     2.0      3    0.4%
#   SF_FR → SF_JUNC_RIGHT                                600    15.0      4    2.5%
#   SF_JUNC_CENTER → SF_JUNC_LEFT                       1440   153.0     18   10.6%
#   SF_JUNC_LEFT → LEFT_STAIR_S2G                       1200   593.0      4   49.4%
#   SF_JUNC_RIGHT → RIGHT_STAIR_S2G                     1200   347.0      4   28.9%
#   LEFT_STAIR_S2G → GF_JUNC_LEFT                       1200   593.0      6   49.4%
#   RIGHT_STAIR_S2G → GF_JUNC_RIGHT                     1200   347.0      6   28.9%
#   TF_FH302 → TF_JUNC_LEFT                              720    53.0      7    7.4%
#   TF_FH304 → TF_JUNC_LEFT                              720    55.0     10    7.6%
#   TF_FH311A → TF_JUNC_CENTER                           720    57.0      8    7.9%
#   TF_FH311B → TF_JUNC_CENTER                           720    49.0      8    6.8%
#   TF_FHCL → TF_JUNC_CENTER                             900    36.0      5    4.0%
#   TF_OAC → TF_JUNC_CENTER                              720    51.0      5    7.1%
#   TF_FHTL → TF_JUNC_CENTER                             720    49.0      7    6.8%
#   TF_FH314 → TF_JUNC_RIGHT                             720    47.0      7    6.5%
#   TF_FH315 → TF_JUNC_RIGHT                             720    47.0      8    6.5%
#   TF_FH316 → TF_JUNC_RIGHT                             720    43.0     10    6.0%
#   TF_FH317 → TF_JUNC_RIGHT                             720    50.0     12    6.9%
#   TF_DO → TF_JUNC_RIGHT                                540     2.0      3    0.4%
#   TF_FR → TF_JUNC_RIGHT                                600    15.0      4    2.5%
#   TF_JUNC_CENTER → TF_JUNC_LEFT                       1440   242.0     18   16.8%
#   TF_JUNC_LEFT → LEFT_STAIR_T2S                       1200   350.0      4   29.2%
#   TF_JUNC_RIGHT → RIGHT_STAIR_T2S                     1200   204.0      4   17.0%
#   LEFT_STAIR_T2S → SF_JUNC_LEFT                       1200   350.0      6   29.2%
#   RIGHT_STAIR_T2S → SF_JUNC_RIGHT                     1200   204.0      6   17.0%
#
#   Evacuation Area        Capacity   Received    Util%
#   ----------------------------------------------------
#   EA_FRONT                   2592      712.0    27.5%
#   EA_LEFT                     499       58.0    11.6%
#   EA_RIGHT                    342      342.0   100.0%
#
#   ✓  No bottlenecks detected.
#
#
# ==========================================================
#   WEEKLY SUMMARY
#   Day            Evacuees      Optimal Z       Status
#   ----------------------------------------------------
#   Monday             2335       96739.00  FEASIBLE
#   Tuesday            2306       95453.00  FEASIBLE
#   Wednesday          2302       95575.00  FEASIBLE
#   Thursday           2346       97790.00  FEASIBLE
#   Friday             2300       95388.00  FEASIBLE
#   Saturday           1112       44600.00  FEASIBLE
#
# =================================================================
#   FIXED WEEKLY EVACUATION ROUTES
#   (Derived from Thursday — worst-case occupancy)
#   Applied uniformly across all days of the week.
# =================================================================
#
#   --- GROUND FLOOR ---
#   GF_FH106        ->  GF_MAINEXIT2 -> EA_FRONT
#   GF_FH107        ->  GF_MAINEXIT2 -> EA_FRONT
#   GF_FH108        ->  GF_MAINEXIT2 -> EA_FRONT
#   GF_FH110        ->  GF_MAINEXIT4 -> EA_LEFT
#   GF_MTLABA       ->  GF_MAINEXIT2 -> EA_FRONT
#   GF_MTLABB       ->  GF_MAINEXIT2 -> EA_FRONT
#   GF_GS           ->  GF_MAINEXIT2 -> EA_FRONT
#   GF_PSR          ->  GF_MAINEXIT2 -> EA_FRONT
#   GF_FR           ->  GF_MAINEXIT2 -> EA_FRONT
#   GF_CSR          ->  GF_MAINEXIT2 -> EA_FRONT
#
#   --- SECOND FLOOR ---
#   SF_FH201A       ->  LEFT_STAIR_S2G -> GF_MAINEXIT2 -> EA_FRONT
#   SF_FH201B       ->  LEFT_STAIR_S2G -> GF_MAINEXIT2 -> EA_FRONT
#   SF_FH202        ->  LEFT_STAIR_S2G -> GF_MAINEXIT2 -> EA_FRONT
#   SF_FH205        ->  LEFT_STAIR_S2G -> GF_MAINEXIT2 -> EA_FRONT
#   SF_FH206        ->  LEFT_STAIR_S2G -> GF_MAINEXIT2 -> EA_FRONT
#   SF_FH207        ->  LEFT_STAIR_S2G -> GF_MAINEXIT2 -> EA_FRONT
#   SF_RE           ->  LEFT_STAIR_S2G -> GF_MAINEXIT2 -> EA_FRONT
#   SF_CSAR         ->  LEFT_STAIR_S2G -> GF_MAINEXIT2 -> EA_FRONT
#   SF_AVRA         ->  RIGHT_STAIR_S2G -> GF_MAINEXIT4 -> EA_LEFT
#   SF_AVRB         ->  RIGHT_STAIR_S2G -> GF_MAINEXIT4 -> EA_LEFT
#   SF_FH208        ->  RIGHT_STAIR_S2G -> GF_MAINEXIT4 -> EA_LEFT
#   SF_FH209        ->  RIGHT_STAIR_S2G -> GF_MAINEXIT4 -> EA_LEFT
#   SF_FH210        ->  RIGHT_STAIR_S2G -> GF_MAINEXIT4 -> EA_LEFT
#   SF_MMR          ->  RIGHT_STAIR_S2G -> GF_MAINEXIT4 -> EA_LEFT
#   SF_STD          ->  RIGHT_STAIR_S2G -> GF_MAINEXIT4 -> EA_LEFT
#   SF_OCL2         ->  RIGHT_STAIR_S2G -> GF_MAINEXIT4 -> EA_LEFT
#   SF_SL           ->  RIGHT_STAIR_S2G -> GF_MAINEXIT4 -> EA_LEFT
#   SF_OCL          ->  RIGHT_STAIR_S2G -> GF_MAINEXIT4 -> EA_LEFT
#   SF_CTA          ->  RIGHT_STAIR_S2G -> GF_MAINEXIT4 -> EA_LEFT
#   SF_CTB          ->  RIGHT_STAIR_S2G -> GF_MAINEXIT4 -> EA_LEFT
#   SF_CTC          ->  RIGHT_STAIR_S2G -> GF_MAINEXIT4 -> EA_LEFT
#   SF_DO           ->  RIGHT_STAIR_S2G -> GF_MAINEXIT4 -> EA_LEFT
#   SF_FR           ->  RIGHT_STAIR_S2G -> GF_MAINEXIT4 -> EA_LEFT
#
#   --- THIRD FLOOR ---
#   TF_FH301A       ->  LEFT_STAIR_T2S -> LEFT_STAIR_S2G -> GF_MAINEXIT2 -> EA_FRONT
#   TF_FH302        ->  LEFT_STAIR_T2S -> LEFT_STAIR_S2G -> GF_MAINEXIT2 -> EA_FRONT
#   TF_FH303        ->  LEFT_STAIR_T2S -> LEFT_STAIR_S2G -> GF_MAINEXIT2 -> EA_FRONT
#   TF_FH304        ->  LEFT_STAIR_T2S -> LEFT_STAIR_S2G -> GF_MAINEXIT2 -> EA_FRONT
#   TF_FH305        ->  LEFT_STAIR_T2S -> LEFT_STAIR_S2G -> GF_MAINEXIT2 -> EA_FRONT
#   TF_FH306        ->  LEFT_STAIR_T2S -> LEFT_STAIR_S2G -> GF_MAINEXIT2 -> EA_FRONT
#   TF_FH307        ->  LEFT_STAIR_T2S -> LEFT_STAIR_S2G -> GF_MAINEXIT2 -> EA_FRONT
#   TF_FH308        ->  LEFT_STAIR_T2S -> LEFT_STAIR_S2G -> GF_MAINEXIT2 -> EA_FRONT
#   TF_FH309        ->  LEFT_STAIR_T2S -> LEFT_STAIR_S2G -> GF_MAINEXIT2 -> EA_FRONT
#   TF_FH311A       ->  LEFT_STAIR_T2S -> LEFT_STAIR_S2G -> GF_MAINEXIT2 -> EA_FRONT
#   TF_FH311B       ->  LEFT_STAIR_T2S -> LEFT_STAIR_S2G -> GF_MAINEXIT2 -> EA_FRONT
#   TF_FHCL         ->  LEFT_STAIR_T2S -> LEFT_STAIR_S2G -> GF_MAINEXIT2 -> EA_FRONT
#   TF_OAC          ->  LEFT_STAIR_T2S -> LEFT_STAIR_S2G -> GF_MAINEXIT2 -> EA_FRONT
#   TF_FHTL         ->  LEFT_STAIR_T2S -> LEFT_STAIR_S2G -> GF_MAINEXIT2 -> EA_FRONT
#   TF_FH314        ->  RIGHT_STAIR_T2S -> RIGHT_STAIR_S2G -> GF_MAINEXIT4 -> EA_LEFT
#   TF_FH315        ->  RIGHT_STAIR_T2S -> RIGHT_STAIR_S2G -> GF_MAINEXIT4 -> EA_LEFT
#   TF_FH316        ->  RIGHT_STAIR_T2S -> RIGHT_STAIR_S2G -> GF_MAINEXIT4 -> EA_LEFT
#   TF_FH317        ->  RIGHT_STAIR_T2S -> RIGHT_STAIR_S2G -> GF_MAINEXIT4 -> EA_LEFT
#   TF_DO           ->  RIGHT_STAIR_T2S -> RIGHT_STAIR_S2G -> GF_MAINEXIT4 -> EA_LEFT
#   TF_FR           ->  RIGHT_STAIR_T2S -> RIGHT_STAIR_S2G -> GF_MAINEXIT4 -> EA_LEFT
#
# =================================================================
#   FIXED ROUTE FEASIBILITY CHECK — ALL DAYS
#   Verifying Thursday-derived routes hold across the week.
# =================================================================
#
#   Monday (FEASIBLE)
#     NOTE  SF_STD: fixed→EA_LEFT, Monday→SF_STD
#
#   Tuesday (FEASIBLE)
#     All rooms reach the same evacuation area as fixed plan.
#
#   Wednesday (FEASIBLE)
#     All rooms reach the same evacuation area as fixed plan.
#
#   Thursday (FEASIBLE)
#     All rooms reach the same evacuation area as fixed plan.
#
#   Friday (FEASIBLE)
#     NOTE  SF_FH210: fixed→EA_LEFT, Friday→SF_FH210
#
#   Saturday (FEASIBLE)
#     NOTE  GF_FH107: fixed→EA_FRONT, Saturday→GF_FH107
#     NOTE  GF_FH108: fixed→EA_FRONT, Saturday→GF_FH108
#     NOTE  GF_MTLABB: fixed→EA_FRONT, Saturday→GF_MTLABB
#     NOTE  SF_FH201A: fixed→EA_FRONT, Saturday→SF_FH201A
#     NOTE  SF_FH201B: fixed→EA_FRONT, Saturday→SF_FH201B
#     NOTE  SF_FH202: fixed→EA_FRONT, Saturday→SF_FH202
#     NOTE  SF_FH206: fixed→EA_FRONT, Saturday→SF_FH206
#     NOTE  SF_RE: fixed→EA_FRONT, Saturday→SF_RE
#     NOTE  SF_CSAR: fixed→EA_FRONT, Saturday→SF_CSAR
#     NOTE  SF_AVRA: fixed→EA_LEFT, Saturday→SF_AVRA
#     NOTE  SF_AVRB: fixed→EA_LEFT, Saturday→SF_AVRB
#     NOTE  SF_FH208: fixed→EA_LEFT, Saturday→EA_FRONT
#     NOTE  SF_FH209: fixed→EA_LEFT, Saturday→EA_FRONT
#     NOTE  SF_FH210: fixed→EA_LEFT, Saturday→SF_FH210
#     NOTE  SF_MMR: fixed→EA_LEFT, Saturday→SF_MMR
#     NOTE  SF_STD: fixed→EA_LEFT, Saturday→EA_FRONT
#     NOTE  SF_OCL2: fixed→EA_LEFT, Saturday→EA_RIGHT
#     NOTE  SF_SL: fixed→EA_LEFT, Saturday→EA_RIGHT
#     NOTE  SF_OCL: fixed→EA_LEFT, Saturday→SF_OCL
#     NOTE  SF_CTA: fixed→EA_LEFT, Saturday→EA_RIGHT
#     NOTE  SF_CTB: fixed→EA_LEFT, Saturday→SF_CTB
#     NOTE  SF_CTC: fixed→EA_LEFT, Saturday→SF_CTC
#     NOTE  SF_DO: fixed→EA_LEFT, Saturday→EA_RIGHT
#     NOTE  SF_FR: fixed→EA_LEFT, Saturday→EA_RIGHT
#     NOTE  TF_FH301A: fixed→EA_FRONT, Saturday→TF_FH301A
#     NOTE  TF_FH303: fixed→EA_FRONT, Saturday→TF_FH303
#     NOTE  TF_FH305: fixed→EA_FRONT, Saturday→TF_FH305
#     NOTE  TF_FH306: fixed→EA_FRONT, Saturday→TF_FH306
#     NOTE  TF_FH307: fixed→EA_FRONT, Saturday→TF_FH307
#     NOTE  TF_FH308: fixed→EA_FRONT, Saturday→TF_FH308
#     NOTE  TF_FH309: fixed→EA_FRONT, Saturday→TF_FH309
#     NOTE  TF_FH314: fixed→EA_LEFT, Saturday→EA_RIGHT
#     NOTE  TF_FH315: fixed→EA_LEFT, Saturday→EA_RIGHT
#     NOTE  TF_FH316: fixed→EA_LEFT, Saturday→EA_RIGHT
#     NOTE  TF_FH317: fixed→EA_LEFT, Saturday→EA_RIGHT
#     NOTE  TF_DO: fixed→EA_LEFT, Saturday→EA_RIGHT
#     NOTE  TF_FR: fixed→EA_LEFT, Saturday→EA_RIGHT
